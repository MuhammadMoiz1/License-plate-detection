# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
Dir='/content/gdrive/My Drive/NumberPlateDetection'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 9.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %% [markdown]
# # **YOLOv8**

# %%
import os
from ultralytics import YOLO

model=YOLO("yolov8n.pt")
# model = YOLO('yolov8n.yaml')

results=model.train(data=os.path.join(Dir,"google_colab_config.yaml"),epochs=20)
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/My Drive/NumberPlateDetection/data/labels/valid.cache... 81 images, 0 backgrounds, 0 corrupt: 100%|██████████| 81/81 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
#                    all         81         81      0.976      0.986      0.986      0.837
# Speed: 0.4ms preprocess, 9.1ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to runs/detect/train32

# %%
import os
from IPython.display import display, Image


folder_path = "runs/detect/train32"

image_files = os.listdir(folder_path)


for image_file in image_files:
    if image_file.endswith(".jpg") or image_file.endswith(".png"):
        display(Image(os.path.join(folder_path, image_file)))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def calculate_metrics(TP, FP, FN, TN):
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall)
    return precision, recall, accuracy, f1_score


TP = 80
FP = 6
FN =  1
TN =  0

precision, recall, accuracy, f1_score = calculate_metrics(TP, FP, FN, TN)
print("Precision:", precision)
print("Recall:", recall)
print("Accuracy:", accuracy)
print("F1 Score:", f1_score)
# Out:
# Precision: 0.9302325581395349
# Recall: 0.9876543209876543
# Accuracy: 0.9195402298850575
# F1 Score: 0.9580838323353293

# %% [markdown]
# # **YOLOv9**

# %%
model1 = YOLO('yolov9c.pt')

results1 = model1.train(data=os.path.join(Dir,"google_colab_config.yaml"), epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 192MB/s]
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model1.val()
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv9c summary (fused): 384 layers, 25320019 parameters, 0 gradients, 102.3 GFLOPs
# val: Scanning /content/gdrive/My Drive/NumberPlateDetection/data/labels/valid.cache... 81 images, 0 backgrounds, 0 corrupt: 100%|██████████| 81/81 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:06<00:00,  1.09s/it]
#                    all         81         81      0.962      0.945      0.988      0.826
# Speed: 0.5ms preprocess, 36.3ms inference, 0.0ms loss, 11.1ms postprocess per image
# Results saved to runs/detect/train42

# %%
import os
from IPython.display import display, Image


folder_path = "runs/detect/train42"

image_files = os.listdir(folder_path)


for image_file in image_files:
    if image_file.endswith(".jpg") or image_file.endswith(".png"):
        display(Image(os.path.join(folder_path, image_file)))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def calculate_metrics(TP, FP, FN, TN):
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall)
    return precision, recall, accuracy, f1_score


TP = 81
FP = 19
FN =  0
TN =  0

precision, recall, accuracy, f1_score = calculate_metrics(TP, FP, FN, TN)
print("Precision:", precision)
print("Recall:", recall)
print("Accuracy:", accuracy)
print("F1 Score:", f1_score)
# Out:
# Precision: 0.81
# Recall: 1.0
# Accuracy: 0.81
# F1 Score: 0.8950276243093923
